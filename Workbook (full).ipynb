# %% [markdown]
# (This workbook contains the entire code for the project. It's been organized into sections so it may be helpful to turn on the Table of Contents view.)

# %% [markdown]
# # I. Setup before building and training model
#
# This section focuses on cleaning, preparing, and preprocessing the data.

# %% [markdown]
# ## Data preparation, part 1: target labels and cleaning
#
# As described in the README, we will be using SCP's diagnostic superclasses (as opposed to the subclasses or individual codes) as the target labels we aim to learn. Some further details:
# - The diagnostic labels for the PTB-XL dataset are all binary yes-or-no labels (though the dataset gives each annotation a confidence score in the range from 0% to 100%), and they are not mutually exclusive. Also, as described in PTB-XL's online page, a given annotation in the dataset can also be written with 0% confidence, which represents an "unknown" confidence. (Any known confidence is always written with a positive confidence value.)
# - Following the example of the authors of [this Github project](https://github.com/helme/ecg_ptbxl_benchmarking) that also analyzes the PTB-XL dataset, I'll simply encode a label as 1 if it shows up at all with any confidence value (including "unknown"), and 0 if it doesn't show up.
# - I'll be removing "NORM", indicating a normal ECG signal, from the superclass labels. I'll also be dropping those individual SCP codes that aren't assigned to a diagnostic superclass.
# - With these choices, the remaining 4 labels are STTC, MI, HYP, and CD, as described in the README. Their positivity rates on the dataset are shown in the output of the below cell.

# %%
# Data cleaning and basic exploratory analysis

import pandas as pd
import numpy as np
import ast # used for evaluating some strings in the csv as Python code snippets

# PTB-XL's dataframe consisting of ECG record numbers and their associated diagnostic annotations.
# Note: the record numbers correspond to record numbers in Physionet's WFDB (Waveform database).
ptbxl_annot_data = pd.read_csv('Data/Original/ptbxl_database.csv')
ptbxl_annot_data.reset_index(drop=True, inplace=True) # we'll just reset the indexing to use integers starting at 0


# Dataframe consisting of all individual SCP codes and how they are grouped into diagnostic subclasses and superclasses.
scp_code_df = pd.read_csv('Data/Original/scp_statements.csv')
scp_code_df = scp_code_df.rename( columns={ scp_code_df.columns[0] : 'scp-code' } )
ptbxl_annot_data['scp_codes_dict'] = ptbxl_annot_data['scp_codes'].apply( lambda x: ast.literal_eval(x) ) # the entries in this column consist of strings containing python code for dictionaries containing the code,confidence pair values for the annotations. we'll evaluate these strings into actual dictionaries
ptbxl_annot_data['scp_codes_dict'] = ptbxl_annot_data['scp_codes_dict'].apply( lambda d : { key : value/100.0 for key,value in d.items() } ) # dividing by 100 to get values in the range [0,1]

diagnostic_superclasses = scp_code_df['diagnostic_class'].dropna().unique().tolist() # get list of SCP superclasses
code_to_class_mapping = scp_code_df.set_index('scp-code')['diagnostic_class'].fillna('Other').to_dict() # "Other" refers to those codes that haven't been assigned to a superclass. Note "Other" isn't included in diagnostic_superclasses, so this will not be included as a label in our model.
code_to_class_mapping.pop('NORM',None); diagnostic_superclasses.remove('NORM') # removing "NORM", representing a normal signal, as a diagnostic label

# Now code_to_class_mapping is a dictionary mapping individual codes to their corresponding SCP superclasses. 
# It only has code,superclass pairs for a code if the code is assigned to a superclass, and that class is not NORM.
# (Note: "NORM" is the only individual SCP code that maps to the superclass "NORM" anyway.)

# Method that maps a dict of individual SCP codes with confidence scores to a dict of SCP superclasses with confidence scores,
# with the confidence of superclass c being the max of the confidences of any of the individual codes b belonging to superclass c,
# with "unknown" confidence being encoded as 0 as in the original dataset.
def convert_to_superclasses( proba_dict ) :
    d = {}
    for c in diagnostic_superclasses :
        probs = [ value for code,value in proba_dict.items() if code_to_class_mapping.get(code,'') == c ]
        if probs : # i.e. if probs is nonempty
            d[c] = max(probs) # using the max confidence of any code within a superclass C as the confidence of C
    return d

ptbxl_annot_data['class_dict'] = ptbxl_annot_data['scp_codes_dict'].apply( convert_to_superclasses )


# Calculate and print the positivity rates of each superclass on the dataset.
pos_rate = { 
    c : ptbxl_annot_data['class_dict'].apply( 
            lambda d : 
                ( int( c in d ) ) # encoding any occurrence of c in the dict as "positive" for class c, for any confidence, even if unknown confidence
        ).mean()
    for c in diagnostic_superclasses 
}
print("Positivity rates (on the whole dataset) for the diagnostic superclasses:")
print(pd.Series(pos_rate).to_string())


# Use an array of confidence values, with the ordering matching the ordering on diagnostic_superclasses,
# instead of using a dictionary of label,confidence pairs.
ptbxl_annot_data['y_superclasses'] = ptbxl_annot_data['class_dict'].apply( 
    lambda d : 
    np.array(
        [ ( -1.0 if ( c in d and d.get(c,-1.0)==0.0 ) # encoding "unknown" confidence as -1.0
            else d.get(c,0.0) ) # otherwise, confidence is encoded as its own value
          for c in diagnostic_superclasses 
        ], 
        dtype=np.float32
    )
)
# Out:
# Positivity rates (on the whole dataset) for the diagnostic superclasses:
# STTC    0.240149
# MI      0.250883
# HYP     0.121519
# CD      0.224689

# %% [markdown]
# ## Data preparation, part 2: signal preprocessing and storage
#
# We use the NeuroKit2 library's signal processing methods to filter and clean our ECG data. (Technical details: we will use a Butterworth bandpass filter, with lowcut at around 0.5Hz to remove ECG baseline wander, and highcut around 40-50Hz to remove signal noise. After the filtering, we also apply Z-scoring to each signal strip.)
# The processed ECG data strips will be stored and loaded using Numpy's methods.
#
# This only needs to be done once, so you can set the PREPROCESSING_FROM_SCRATCH switch in the below cell to False if this has already been done.

# %% [markdown]
# ### Some switches

# %%
LOAD_FULL_SIGNAL_DATA_INTO_RAM = False
# if True, the entire signal data is saved into a single file and loaded entirely into RAM for training.
# if False, the signal data is saved in separate files, each of which is read individually during training.

PREPROCESSING_FROM_SCRATCH = False # can set to False if preprocessing was already completed and preprocessed signal data was saved to disk

# NOTE: whenever you do a run with a value for LOAD_FULL_SIGNAL_DATA_INTO_RAM you haven't used before, 
# you have to set PREPROCESSING_FROM_SCRATCH=True to allow the preprocessed signal data to be generated in the new needed format.

# %%
# Preprocess signals, save to disk if needed, load from disk if needed

import wfdb # Waveform Database (WFDB), contains the signal data that has been labeled (by human clinicians) in the PTB-XL dataset.

import neurokit2 as nk # NeuroKit2 library. We'll use it for signal filtering and preprocessing.

all_sigs = None


# Here we'll create some directories that we need to exist for now and for later as well
from pathlib import Path
for f in ['Preprocessed' , 'Postprocessed', 'Checkpoint'] :
    Path('Data/Preprocessed').mkdir(parents=True, exist_ok=True)
Path('Results').mkdir(parents=True, exist_ok=True)


# Method to load the signals
def get_normalized_ptbxl_sig_at_idx( idx:int ) -> np.ndarray :
    
    sig,metadata = wfdb.rdsamp( # note: WFDB metadata will not be used
        # Note: "hr" here means higher sampling rate. The signal data comes in 500Hz and 100Hz versions, and we'll use the 500Hz version.
        'Data/Original/' + ptbxl_annot_data['filename_hr']
                 .iloc[idx] ,  
            # Note: ^ using iloc here, so idx starts at 0.
            # Note in the actual pandas indexing of ptbxl_annot_data, the index is 1,2,3,... instead of 0,1,2,... .
        return_res=32 , # use 32-bit float, instead of the default which is 64-bit. My MPS GPU apparently needs 32-bit
    ) 

    sig = sig.T 
    # After transposing, sig is now of shape (12,5000). 
    # Here 12 is for the 12 channels, or "leads" as they're called in ECG contexts.
    # And 5000 samples = 10 seconds * 500 Hz sampling rate . 
    
    for l in range(12):  
        # Z-score
        sig[l] = (sig[l] - np.mean(sig[l])) / max(np.std(sig[l]),1e-5) 

    # # Below was used for debugging purposes. It appears one signal strip has all zeros in leads 11 & 12.
    # # We'll just keep that one, because there's only one such strip out of a database of over 20k strips, so it shouldn't affect training too much.
    #
    # for l in range(12): 
    #     try:
    #         with np.errstate(divide='raise', invalid='raise'):
    #             result = (sig[l] - np.mean(sig[l])) / np.std(sig[l])
    #             sig[l] = result
    #     except FloatingPointError:
    #         sig[l] = (sig[l] - np.mean(sig[l])) / max(np.std(sig[l]),1e-5) # Normalize each channel/lead: shift to mean=0 and rescale to stddev=1
    #         print(f"Problematic behavior in signal {idx}.")
    #         np.savetxt('/Users/indraneel/Desktop/sig.csv', sig.T , delimiter=",")
    #         break
    
    return sig


# Method to handle signal filtering and processing
def preprocess_sig( sig : np.ndarray ) -> np.ndarray :

    # Applying a signal filter from the NeuroKit2 library 
    filtered_sig = nk.signal_filter(
        signal = sig, 
        sampling_rate=500., 
        lowcut=0.5,   # Removes slow baseline wander
        highcut=45.0, # Removes high-frequency signal noise
        method="butterworth", order=4 # Butterworth order-4 filter
    )

    return filtered_sig.astype(np.float32)



Num_signals = len(ptbxl_annot_data) # Total number of strips of ECG data, in the entire dataset



## The code below generates the preprocessed signal data and saves it to the hard disk. 
## (This only needs to be done once. After it is done, the PREPROCESSING_FROM_SCRATCH switch can be commented out.) 



# Preprocess the signals and save the filtered signals to files.

import time

if PREPROCESSING_FROM_SCRATCH :

    start_time = time.time()
    
    print("Preprocessing signal data")
    
    if LOAD_FULL_SIGNAL_DATA_INTO_RAM :
        all_sigs = np.zeros( (Num_signals, 12, 5000) )
    
    for i in range(Num_signals) :
    
        if i % 1000 == 0 :
            print(f"Finished preprocessing {i} out of {Num_signals} signals.")
    
        sig = get_normalized_ptbxl_sig_at_idx(i)
        sig = preprocess_sig(sig)
    
        if LOAD_FULL_SIGNAL_DATA_INTO_RAM :
            all_sigs[i] = sig
        else :
            np.save(f'Data/Preprocessed/preprocessed_sig_{i}.npy', sig)
    
    if LOAD_FULL_SIGNAL_DATA_INTO_RAM :
        np.savez(f'Data/Preprocessed/all_sigs.npz', all_sigs=all_sigs)
    else :
        all_sigs = True
    
    end_time = time.time()
    elapsed = end_time - start_time
    print(f"Elapsed time during signal preprocessing: {elapsed:.3f} seconds") 


## Load in the preprocessed signal data.

import time

if LOAD_FULL_SIGNAL_DATA_INTO_RAM and all_sigs is None : # this happens iff PREPROCESSING_FROM_SCRATCH and LOAD_FULL_SIGNAL_DATA_INTO_RAM are both False
    start_time = time.time()
    with np.load('Data/Preprocessed/all_sigs.npz') as data :
        all_sigs = data['all_sigs']
    end_time = time.time(); elapsed = end_time - start_time
    print(f"Elapsed time during signal loading: {elapsed:.3f} seconds")

# %% [markdown]
# ### Setup with Pytorch Datasets

# %% [markdown]
# *Note: to handle issues with multiprocessing during training, I've put the ECG_Dataset class into its own separate python file, ECG_Dataset.py.*

# %% [markdown]
# ### Split into folds for cross-validation
#
# The PTB-XL database already provides its own recommended stratified 10-fold cross-validation splitting, so we will use this splitting.

# %%
# Split into folds

# This code is to keep track of the indices corresponding to each fold.
# Here, fold_idxlists[i] is itself a list of indices corresponding to fold i. 
# Note here i goes from 0 to 9. Fold i here corresopnds to what's labeled as fold i+1 in the original dataset
fold_idxlists = [ 
    np.where(( ptbxl_annot_data['strat_fold'] == i+1  ).to_list())[0] # list of indices at which ptbxl_annot_data['strat_fold'] has value i (i.e., at which it having value i is True(0th value) instead of False(1st value))
    for i in range(11)
]

# %% [markdown]
# # II. Training and results for base model
#
# This section focuses on setting up and training a "base" deep-learning model to classify the data.
# A basic description of the architecture of the "base" model is as follows: the "bottom" submodule is a 1-D CNN-based feature extractor, and this feature extractor is followed by a classifier "head/top" consisting of a simple dense-layer network.
#
# This section also has some switches and hyperparameters to tune, shown in the code below.
#
# In the following section III we will perform an experiment in which we replace the dense classifier head of the pre-trained base model with other non-deep ML models for classification, and compare the performance of these models (including the original base model).

# %% [markdown]
# ## Switches and tunable parameters

# %% [markdown]
# ### Switches involving steps in training process

# %%
DOING_TRAINING = True

LOAD_CHECKPOINT_BEFORE_TRAINING = False # if False, the base model starts completely "from scratch"

SAVE_CHECKPOINT_AFTER_TRAINING  = True

CALCULATE_FEATURE_EMBS = True # if False, the code will assume the feature embeddings have already been calculated and saved to a file

# %% [markdown]
# ### Tunable training hyperparameters

# %%
# Training, large-scale parameters  
BATCH_SIZE = 32
MAX_NUM_EPOCHS = 50

# Training, details
LEARNING_RATE = 1e-3
WEIGHT_DECAY = 1e-4
P_DROPOUT = 0.3

# Decision thresholds between positive and negative for labels
DECISION_THRESHOLD_FOR_TARGET_IN_LOSS     = 0.00 
DECISION_THRESHOLD_FOR_TARGET_IN_SCORING  = 0.00 
DECISION_THRESHOLD_FOR_HARD_PRED          = 0.00

# Note:
#  If threshold  > 0 , any annotation with confidence >= threshold is treated as positive, otherwise negative.
#  If threshold == 0 , any annotation with confidence  > 0         is treated as positive, otherwise negative.
#  Note: Strodthoff et al. treat the target label as positive if the corresponding SCP code shows up at all, even with unknown confidence.

# %% [markdown]
# ### Hyperparameters for base model design
#
# See the code under "Base model construction" below to see exactly how NUM_LAYERS_IN_BASE_MODEL_HEAD is used in designing the model.

# %%
NUM_LAYERS_IN_BASE_MODEL_HEAD = 2 # number of layers, including the output layer!
# Must be a positive integer in the range [1,7].

# %% [markdown]
# ## Base model construction
#
# The base model consists of a feature-extraction "bottom" portion and a classification "top/head" portion. The feature extractor consists of a sequence of 1-dimensional convolution layers, with output that should be viewed as a feature embedding of the original inputted ECG signal. The classification head consists of a couple of dense layers. These will all be trained simultaneously using SGD.

# %%
# Base model class

import torch
import torch.nn as nn


class ECG_Classifier( nn.Module ) :
    
    def __init__(self , dropout_p : float=P_DROPOUT) : 
        super().__init__()

        # Keeps track of number of training epochs undergone
        self._num_epochs=0

        
        # 1D CNN-based feature extractor
        
        self.conv_block1 = nn.Sequential(
            nn.Conv1d(in_channels=12, out_channels=32, kernel_size=15, stride=1, padding=7) ,
                nn.BatchNorm1d(32) , nn.ReLU(inplace=True) ,
            nn.Conv1d(in_channels=32, out_channels=32, kernel_size=15, stride=1, padding=7) ,
                nn.BatchNorm1d(32) , nn.ReLU(inplace=True) ,
            nn.MaxPool1d(kernel_size=2, stride=2) ,
        )
        self.conv_block2 = nn.Sequential(
            nn.Conv1d(in_channels=32, out_channels=64, kernel_size=11, stride=1, padding=5) ,
                nn.BatchNorm1d(64) , nn.ReLU(inplace=True) ,
            nn.Conv1d(in_channels=64, out_channels=64, kernel_size=11, stride=1, padding=5) ,
                nn.BatchNorm1d(64) , nn.ReLU(inplace=True) ,
            nn.MaxPool1d(kernel_size=2, stride=2) ,
        )
        self.conv_block3 = nn.Sequential(
            nn.Conv1d(in_channels=64, out_channels=128, kernel_size=7, stride=1, padding=3) ,
                nn.BatchNorm1d(128) , nn.ReLU(inplace=True) ,
            nn.Conv1d(in_channels=128, out_channels=128, kernel_size=7, stride=1, padding=3) ,
                nn.BatchNorm1d(128) , nn.ReLU(inplace=True) ,
            nn.MaxPool1d(kernel_size=2, stride=2) ,
        )
        self.conv_block4 = nn.Sequential(
            nn.Conv1d(in_channels=128, out_channels=256, kernel_size=5, stride=1, padding=2) ,
                nn.BatchNorm1d(256) , nn.ReLU(inplace=True) ,
            nn.Conv1d(in_channels=256, out_channels=256, kernel_size=5, stride=1, padding=2) ,
                nn.BatchNorm1d(256) , nn.ReLU(inplace=True) ,
            nn.MaxPool1d(kernel_size=2, stride=2) ,
        )

        self.global_pool = nn.AdaptiveAvgPool1d(output_size=1)


        # Dense classifier head

        if NUM_LAYERS_IN_BASE_MODEL_HEAD not in [2,3,4,5,6,7] :
            raise ValueError("NUM_LAYERS_IN_BASE_MODEL_HEAD must be in [2,3,4,5,6,7].")
        
        head_layers = []
        for i in range(NUM_LAYERS_IN_BASE_MODEL_HEAD-1) :
            head_layers.extend([
                  nn.Dropout(p=dropout_p) ,
                nn.Linear( 2 ** (8-i) , 2 ** (8-i-1) ) ,
                 nn.ReLU(inplace=True) 
            ])
        head_layers.extend([
              nn.Dropout(p=dropout_p) ,
            nn.Linear( 2 ** (8-NUM_LAYERS_IN_BASE_MODEL_HEAD+1) , len(diagnostic_superclasses) )
            # Note: since we are doing "No" activation in the final layer, the output should be interpreted as logits.
        ]) 

        self.classifier_head = nn.Sequential( * head_layers )

        

    def feature_extraction(self , x: torch.Tensor) -> torch.Tensor :
        # Input x has shape (B:=batch_size, 12, 5000) .
        # Output is a feature embedding of shape (B,256).

        x = self.conv_block1(x)		    # (B, 32, 2500)
        x = self.conv_block2(x)		    # (B, 64, 1250)
        x = self.conv_block3(x)		    # (B, 128, 625)
        x = self.conv_block4(x)		    # (B, 256, 312)

        x = self.global_pool(x)			# (B, 256, 1)
        x = x.squeeze(-1)				# (B, 256)

        return x

    def forward(self, x: torch.Tensor) -> torch.Tensor :
        # Input x has shape (B:=batch_size, 12, 5000) .
        # Output is logits of shape (B, Num_classes) .
        
        x = self.feature_extraction(x)  # (B, 256)

        x = self.classifier_head(x)		# (B, # of diagnostic classes)

        return x

# %% [markdown]
# ## Training setup
#
# __Train-test split__: following the suggestion given at the PTB-XL dataset's online page, we use its provided stratified splitting of the dataset into folds, with folds 1-8 for training, fold 9 for validation, and fold 10 for testing.
#
# See the code below to see other choices made in setting up for training the base model.

# %%
# Code to set up for training

from torch.utils.data import DataLoader

from sklearn.metrics import average_precision_score as auprc , roc_auc_score as auroc

from ECG_Dataset import ECG_Dataset # importing from my ECG_Dataset.py file




running_best_model = None
running_best_score = 0.0


# Setting up GPU
# I'm running this on my Mac with M3 chip, so I'll use an MPS.
if torch.backends.mps.is_available():
    device = torch.device("mps")
    device_used = 'mps'
    print("GPU (MPS) is available and will be used as the torch device.")
else:
    device = torch.device("cpu")
    device_used = 'cpu'
    print("MPS not available, using CPU as torch device.")


# Weighting in loss, can be helpful due to imbalance between positive and negative classes.
# Should be (# negative)/(# positive).
# Be sure to only use the training set!
if DECISION_THRESHOLD_FOR_TARGET_IN_LOSS>0.0 :
    pos_weight = torch.tensor([
          ptbxl_annot_data[ ptbxl_annot_data['strat_fold'].between(1, 8) ]['y_superclasses'].apply( lambda y : 
                                     int(y[c]<DECISION_THRESHOLD_FOR_TARGET_IN_LOSS)
                                   ).sum() 
          / 
          ( ptbxl_annot_data[ ptbxl_annot_data['strat_fold'].between(1, 8) ]['y_superclasses'].apply( lambda y : 
                                     int(y[c]>=DECISION_THRESHOLD_FOR_TARGET_IN_LOSS) 
                                   ).sum() 
            + 1e-4 # just in case, to avoid division by zero errors
          ) 
        for c in range(len(diagnostic_superclasses))
    ], dtype=torch.float32, device=device)
elif DECISION_THRESHOLD_FOR_TARGET_IN_LOSS==0.0 :
    pos_weight = torch.tensor([
          ptbxl_annot_data[ ptbxl_annot_data['strat_fold'].between(1, 8) ]['y_superclasses'].apply( lambda y : 
                                     int(y[c]==0.0)
                                   ).sum() 
          / 
          ( ptbxl_annot_data[ ptbxl_annot_data['strat_fold'].between(1, 8) ]['y_superclasses'].apply( lambda y : 
                                     int(y[c]>=0.0) 
                                   ).sum() 
            + 1e-4 # just in case, to avoid division by zero errors
          ) 
        for c in range(len(diagnostic_superclasses))
    ], dtype=torch.float32, device=device)


# Loss function
criterion = nn.BCEWithLogitsLoss( pos_weight=pos_weight )


# Instantiate our classifier model. Note this model is completely uninitialized and unlearned.
model = ECG_Classifier().to(device)



# Full dataset, stored in an instance of ECG_Dataset.
if LOAD_FULL_SIGNAL_DATA_INTO_RAM :
    full_dataset = ECG_Dataset(
        labels = ptbxl_annot_data['y_superclasses'].copy() , 
        all_sigs = all_sigs ,
        callable_sigloading = False ,
        threshold = DECISION_THRESHOLD_FOR_TARGET_IN_LOSS
    )
else :
    full_dataset = ECG_Dataset(
        labels = ptbxl_annot_data['y_superclasses'].copy() , 
        callable_sigloading = True ,
        threshold = DECISION_THRESHOLD_FOR_TARGET_IN_LOSS
    )



# Method to run one epoch. Can do "train" mode or "validation" mode.
def run_one_epoch(
    model : ECG_Classifier ,
    optimizer ,
    data_loader : DataLoader ,
    validation_mode : bool = False ,
    criterion = criterion ,
) :

    running_loss = 0.0 
    num_examples = 0
    batch_count=0

    # These lists are over one epoch
    logit_pred_list = [] 
    target_list = []
    target_extremized_list = []

    def do_epoch() :
        nonlocal running_loss,num_examples,batch_count,logit_pred_list,target_list,target_extremized_list # so that we can access these variables that belong to run_one_epoch()
        
        for batch in data_loader :
            x,y = batch
            x , y = x.to(device) , y.to(device) 
        
            logit_pred = model(x) # Feedforward
            loss = criterion( logit_pred , y ) # Compute loss
    
            # Batch size should generally always be the same, the only exception being when there's a remainder at the end.
            this_batch_size = x.shape[0]
            num_examples += this_batch_size
            running_loss += loss.item() * this_batch_size

            
            logit_pred_list.append( logit_pred.detach().cpu() )
            target_list.append( y.detach().cpu() )
            target_extremized_list.append(
                torch.where( 
                    ( y >= DECISION_THRESHOLD_FOR_TARGET_IN_SCORING ) 
                    if DECISION_THRESHOLD_FOR_TARGET_IN_SCORING>0.0 
                    else ( y > 0.0 )
                , 1.0 , 0.0 
                ) 
                # (Target decision threshold used in *loss* is in ECG_Dataset)
            )

            if not validation_mode :
                optimizer.zero_grad() # zero out gradients
                loss.backward() # Backpropagate
                optimizer.step()
        
            batch_count +=1
            
        logit_pred_tensor = torch.cat(logit_pred_list)
        probs_pred_tensor = torch.sigmoid(logit_pred_tensor)

        target_extremized_tensor = torch.cat(target_extremized_list)

        if not validation_mode :
            model._num_epochs += 1


        # Collect results of epoch

        score = auprc( target_extremized_tensor.detach().cpu().numpy() , probs_pred_tensor.detach().cpu().numpy() , average='macro' )

        auroc_score = auroc( target_extremized_tensor.detach().cpu().numpy() , probs_pred_tensor.detach().cpu().numpy() , 
                             average='macro' )

        per_class_scores = []
        for c in range(len(diagnostic_superclasses)) :
            probs_pred_c = probs_pred_tensor [:,c]
            score_c = auprc( target_extremized_tensor.detach().cpu().numpy() [:,c] , probs_pred_c )
            per_class_scores.append( score_c )

        
        return {
            'avg_loss' : running_loss / num_examples ,
            'auprc' : score ,
            'per_class_scores' : per_class_scores ,
            'auroc' : auroc_score ,
        }

    
    if validation_mode :
        model.eval()
        with torch.no_grad() :
            return do_epoch()
    else :
        model.train()
        return do_epoch()





# Method for the full training run
def FULL_TRAINING_LOOP() :
    
    
    global running_best_model, running_best_score

    from torch.utils.data import Subset,DataLoader
    
    import matplotlib.pyplot as plt
    from cycler import cycler
    from matplotlib.ticker import MaxNLocator
    import IPython # using IPython to draw graphs that update in real time
    import time
    import random
    import itertools
    import gc
    
    
    # IPython: create handles for IPython displays where we'll show graphs
    plot_handles = [ IPython.display.display(display_id=True) for _ in range(4) ] # we'll display 4 graphs
    
    t_start = time.time()
    
        
    train_loss_list , val_loss_list , val_score_list  = [] , [] , []
    per_class_scores = [ [] for _ in range(len(diagnostic_superclasses)) ]
    auroc_scores = []

    ### TODO: get rid of "trial" stuff below, just use original model.


    # Optimization engine
    optimizer = torch.optim.AdamW( # using AdamW optimizer
        model.parameters(),
        lr=LEARNING_RATE,
        weight_decay=WEIGHT_DECAY
    )

    # Next, create the dataloaders. # Make sure not to do this every individual epoch! This will cause memory usage to explode.

    ## Train-test split: we will use holdout validation as described earlier.

    # Common arguments for both the trainset and valset dataloaders.
    args = {
        'batch_size': BATCH_SIZE ,
        
        # These next args should speed up training.
        'num_workers': 2 ,
        'persistent_workers': True ,
        'prefetch_factor': 2 ,
        'pin_memory': False if device_used=='mps' else True ,
    }

    train_idxs = []
    for j in range(8) : 
        train_idxs.extend( fold_idxlists[j] )
    val_idxs = np.concatenate([ fold_idxlists[8]  , # using fold 9 (index 8) in the validation set.
                                #fold_idxlists[9]   # not using fold 10 (index 9) in validation. We'll use it as a test set instead.
                              ])


    # Create the training and validation dataloaders
    train_loader = DataLoader( Subset( full_dataset , train_idxs ) , 
                                   shuffle=  True , **args )
    val_loader   = DataLoader( Subset( full_dataset , val_idxs ) , 
                                   shuffle= False , **args )

    
    # Training run loop. Runs epoch-by-epoch
    for epoch in range(MAX_NUM_EPOCHS) :
    
        
    
        # Training 
        
        t1 = time.time()
    
        train_results = run_one_epoch(model, optimizer=optimizer, data_loader= train_loader, validation_mode= False)
        
        train_loss_list.append(train_results['avg_loss'])
    
        # Validation
    
        val_results = run_one_epoch(model, optimizer=optimizer, data_loader= val_loader, validation_mode= True)
        
        val_loss_list.append(val_results['avg_loss'])
        score = val_results['auprc']
        val_score_list.append(score)
        auroc_scores.append(val_results['auroc'])

        for c in range(len(diagnostic_superclasses)) :
            per_class_scores[c].append( val_results['per_class_scores'][c] )
    
        t2 = time.time() 


        # Keep track of best-scoring model

        if score > running_best_score :
            running_best_model = ECG_Classifier().to(device)
            running_best_model.load_state_dict( model.state_dict() )
            running_best_model._num_epochs = model._num_epochs
            running_best_score = score
            
        
    
        # Plot and print results (updates every epoch):

        # avg losses
        fig1,ax1 = plt.subplots()
        ax1.plot(range(1,epoch+2), train_loss_list, label='Train loss',color='blue')
        ax1.plot(range(1,epoch+2), val_loss_list, label='Val loss',color='green')
        ax1.set_title("Avg losses for current fold as a function of epoch");ax1.set_xlabel("Epoch");ax1.set_ylabel("Loss (BCE)");ax1.legend()
        ax1.xaxis.set_major_locator(MaxNLocator(integer=True)) # force integer ticks on the X-axis
        plot_handles[0].update(fig1)
        plt.close(fig1)

        # macro AUPRC score
        fig2,ax2 = plt.subplots()
        ax2.plot(range(1,epoch+2), val_score_list, color='gold')
        ax2.set_title("Val score (macro AUPRC) for current fold as a function of epoch");ax2.set_xlabel("Epoch");ax2.set_ylabel("Val score (macro-averaged AUPRC)")
        ax2.xaxis.set_major_locator(MaxNLocator(integer=True)) # force integer ticks on the X-axis
        plot_handles[1].update(fig2)
        plt.close(fig2)

        # per-label AUPRC score
        fig3,ax3 = plt.subplots()
        colors = plt.get_cmap('tab20') ( np.arange(len(diagnostic_superclasses)) ) # colors using the tab20 palette
        plt.gca().set_prop_cycle(cycler(color=colors)) # set the graph to use these colors
        for c in range(len(diagnostic_superclasses)) :
            ax3.plot( range(1,epoch+2) , per_class_scores[c] , label=f'{diagnostic_superclasses[c]}' )
        ax3.set_title("Val score (AUPRC) for current fold as a function of epoch for individual labels");
        ax3.set_xlabel("Epoch");ax3.set_ylabel("Val score (AUPRC)")
        ax3.legend()
        ax3.xaxis.set_major_locator(MaxNLocator(integer=True)) # force integer ticks on the X-axis
        plot_handles[2].update(fig3)
        plt.close(fig3)

        # 
        fig4,ax4 = plt.subplots()
        ax4.plot(range(1,epoch+2), auroc_scores, color='orange')
        ax4.set_title("Val score (macro AUROC) for current fold as a function of epoch");ax4.set_xlabel("Epoch");ax4.set_ylabel("Val score (macro-averaged AUROC)")
        ax4.xaxis.set_major_locator(MaxNLocator(integer=True)) # force integer ticks on the X-axis
        plot_handles[3].update(fig4)
        plt.close(fig4)
        
        print(f"Finished epoch #{epoch+1 : 3}. | Time elapsed during epoch: {(t2-t1)/60.0 : 6.3f}mins" , end='')
        print(f" | Time since start: {(t2-t_start)/60.0 : 7.3f}mins" , end='')
        print(f" | Train avg loss = {train_results['avg_loss'] : 6.3f}", end='')
        print(f" | Val avg loss = {val_results['avg_loss']: 6.3f}", end='')
        print(f" | Val score = {val_results['auprc']: 6.4f}")
# Out:
# GPU (MPS) is available and will be used as the torch device.

# %% [markdown]
# ### Load model checkpoint
#
# (If the "load checkpoint" switch is turned off, this section is automatically skipped.)

# %%
# Load model checkpoint

if LOAD_CHECKPOINT_BEFORE_TRAINING :

    from pathlib import Path
    
    # Function to get the Path of the most recently modified file with a given extension in a given directory
    def most_recent_file(directory, extension):
        directory = Path(directory)
        extension = extension if extension.startswith(".") else "." + extension
        files = directory.glob(f"*{extension}")
        try:
            return max(files, key=lambda p: p.stat().st_mtime)
        except ValueError:
            return None
    
    # Open and load the most recently modified checkpoint file
    newest = most_recent_file('Data/Checkpoint' , 'pth')
    checkpoint = torch.load(newest , weights_only=False)
    print(f"Opened file \"{newest}\" as checkpoint.")
    model.load_state_dict(checkpoint['model_state'])
    # optimizer.load_state_dict(checkpoint['optimizer_state'])
    model._num_epochs = checkpoint['num_epochs_completed']

else :

    print("Did not load a checkpoint, starting the base model from scratch.")
# Out:
# Did not load a checkpoint, starting the base model from scratch.

# %% [markdown]
# ## Training loop execution and results

# %% [markdown]
# The cell below executes the full training loop of the base model. As it runs, the cell produces some plots and log output giving info about losses, scores, training time, and other measurables as training occurs in real time.
#
# (If the DOING_TRAINING switch is False, then the training loop is not executed.)

# %%
FULL_TRAINING_LOOP() if DOING_TRAINING else None
# Out:
# Finished epoch #  1. | Time elapsed during epoch:  1.149mins | Time since start:   1.155mins | Train avg loss =  0.316 | Val avg loss =  0.293 | Val score =  0.6624
# Finished epoch #  2. | Time elapsed during epoch:  1.271mins | Time since start:   2.432mins | Train avg loss =  0.278 | Val avg loss =  0.274 | Val score =  0.7001
# Finished epoch #  3. | Time elapsed during epoch:  1.424mins | Time since start:   3.859mins | Train avg loss =  0.268 | Val avg loss =  0.264 | Val score =  0.7114
# Finished epoch #  4. | Time elapsed during epoch:  1.364mins | Time since start:   5.226mins | Train avg loss =  0.260 | Val avg loss =  0.261 | Val score =  0.7223
# Finished epoch #  5. | Time elapsed during epoch:  1.244mins | Time since start:   6.473mins | Train avg loss =  0.255 | Val avg loss =  0.260 | Val score =  0.7141
# Finished epoch #  6. | Time elapsed during epoch:  1.279mins | Time since start:   7.755mins | Train avg loss =  0.250 | Val avg loss =  0.255 | Val score =  0.7183
# Finished epoch #  7. | Time elapsed during epoch:  1.276mins | Time since start:   9.034mins | Train avg loss =  0.245 | Val avg loss =  0.253 | Val score =  0.7257
# Finished epoch #  8. | Time elapsed during epoch:  1.271mins | Time since start:  10.308mins | Train avg loss =  0.244 | Val avg loss =  0.249 | Val score =  0.7346
# Finished epoch #  9. | Time elapsed during epoch:  1.281mins | Time since start:  11.592mins | Train avg loss =  0.241 | Val avg loss =  0.248 | Val score =  0.7340
# Finished epoch # 10. | Time elapsed during epoch:  1.283mins | Time since start:  12.879mins | Train avg loss =  0.237 | Val avg loss =  0.254 | Val score =  0.7345
# Finished epoch # 11. | Time elapsed during epoch:  1.275mins | Time since start:  14.157mins | Train avg loss =  0.236 | Val avg loss =  0.248 | Val score =  0.7400
# Finished epoch # 12. | Time elapsed during epoch:  1.284mins | Time since start:  15.445mins | Train avg loss =  0.233 | Val avg loss =  0.251 | Val score =  0.7328
# Finished epoch # 13. | Time elapsed during epoch:  1.278mins | Time since start:  16.725mins | Train avg loss =  0.230 | Val avg loss =  0.260 | Val score =  0.7317
# Finished epoch # 14. | Time elapsed during epoch:  1.293mins | Time since start:  18.022mins | Train avg loss =  0.227 | Val avg loss =  0.247 | Val score =  0.7408
# Finished epoch # 15. | Time elapsed during epoch:  1.273mins | Time since start:  19.298mins | Train avg loss =  0.225 | Val avg loss =  0.243 | Val score =  0.7431
# Finished epoch # 16. | Time elapsed during epoch:  1.278mins | Time since start:  20.579mins | Train avg loss =  0.223 | Val avg loss =  0.251 | Val score =  0.7358
# Finished epoch # 17. | Time elapsed during epoch:  1.282mins | Time since start:  21.864mins | Train avg loss =  0.221 | Val avg loss =  0.249 | Val score =  0.7321
# Finished epoch # 18. | Time elapsed during epoch:  1.276mins | Time since start:  23.143mins | Train avg loss =  0.220 | Val avg loss =  0.249 | Val score =  0.7403
# Finished epoch # 19. | Time elapsed during epoch:  1.274mins | Time since start:  24.420mins | Train avg loss =  0.217 | Val avg loss =  0.246 | Val score =  0.7364
# Finished epoch # 20. | Time elapsed during epoch:  1.294mins | Time since start:  25.717mins | Train avg loss =  0.217 | Val avg loss =  0.262 | Val score =  0.7341
# Finished epoch # 21. | Time elapsed during epoch:  1.286mins | Time since start:  27.006mins | Train avg loss =  0.213 | Val avg loss =  0.248 | Val score =  0.7378
# Finished epoch # 22. | Time elapsed during epoch:  1.295mins | Time since start:  28.304mins | Train avg loss =  0.212 | Val avg loss =  0.250 | Val score =  0.7359
# Finished epoch # 23. | Time elapsed during epoch:  1.278mins | Time since start:  29.585mins | Train avg loss =  0.209 | Val avg loss =  0.252 | Val score =  0.7275
# Finished epoch # 24. | Time elapsed during epoch:  1.280mins | Time since start:  30.868mins | Train avg loss =  0.206 | Val avg loss =  0.253 | Val score =  0.7376
# Finished epoch # 25. | Time elapsed during epoch:  1.292mins | Time since start:  32.164mins | Train avg loss =  0.206 | Val avg loss =  0.244 | Val score =  0.7382
# Finished epoch # 26. | Time elapsed during epoch:  1.280mins | Time since start:  33.448mins | Train avg loss =  0.205 | Val avg loss =  0.256 | Val score =  0.7302
# Finished epoch # 27. | Time elapsed during epoch:  1.288mins | Time since start:  34.739mins | Train avg loss =  0.203 | Val avg loss =  0.255 | Val score =  0.7313
# Finished epoch # 28. | Time elapsed during epoch:  1.283mins | Time since start:  36.026mins | Train avg loss =  0.200 | Val avg loss =  0.253 | Val score =  0.7348
# Finished epoch # 29. | Time elapsed during epoch:  1.286mins | Time since start:  37.314mins | Train avg loss =  0.198 | Val avg loss =  0.254 | Val score =  0.7367
# Finished epoch # 30. | Time elapsed during epoch:  1.282mins | Time since start:  38.602mins | Train avg loss =  0.196 | Val avg loss =  0.250 | Val score =  0.7357
# Finished epoch # 31. | Time elapsed during epoch:  1.281mins | Time since start:  39.886mins | Train avg loss =  0.193 | Val avg loss =  0.262 | Val score =  0.7352
# Finished epoch # 32. | Time elapsed during epoch:  1.282mins | Time since start:  41.171mins | Train avg loss =  0.191 | Val avg loss =  0.257 | Val score =  0.7343
# Finished epoch # 33. | Time elapsed during epoch:  1.275mins | Time since start:  42.449mins | Train avg loss =  0.190 | Val avg loss =  0.264 | Val score =  0.7339
# Finished epoch # 34. | Time elapsed during epoch:  1.273mins | Time since start:  43.726mins | Train avg loss =  0.188 | Val avg loss =  0.263 | Val score =  0.7393
# Finished epoch # 35. | Time elapsed during epoch:  1.271mins | Time since start:  45.001mins | Train avg loss =  0.185 | Val avg loss =  0.268 | Val score =  0.7277
# Finished epoch # 36. | Time elapsed during epoch:  1.278mins | Time since start:  46.282mins | Train avg loss =  0.183 | Val avg loss =  0.262 | Val score =  0.7315
# Finished epoch # 37. | Time elapsed during epoch:  1.280mins | Time since start:  47.566mins | Train avg loss =  0.181 | Val avg loss =  0.263 | Val score =  0.7355
# Finished epoch # 38. | Time elapsed during epoch:  1.273mins | Time since start:  48.842mins | Train avg loss =  0.179 | Val avg loss =  0.269 | Val score =  0.7287
# Finished epoch # 39. | Time elapsed during epoch:  1.280mins | Time since start:  50.125mins | Train avg loss =  0.176 | Val avg loss =  0.270 | Val score =  0.7298
# Finished epoch # 40. | Time elapsed during epoch:  1.271mins | Time since start:  51.398mins | Train avg loss =  0.174 | Val avg loss =  0.283 | Val score =  0.7200
# Finished epoch # 41. | Time elapsed during epoch:  1.274mins | Time since start:  52.676mins | Train avg loss =  0.170 | Val avg loss =  0.276 | Val score =  0.7276
# Finished epoch # 42. | Time elapsed during epoch:  1.270mins | Time since start:  53.949mins | Train avg loss =  0.169 | Val avg loss =  0.280 | Val score =  0.7210
# Finished epoch # 43. | Time elapsed during epoch:  1.269mins | Time since start:  55.222mins | Train avg loss =  0.165 | Val avg loss =  0.291 | Val score =  0.7158
# Finished epoch # 44. | Time elapsed during epoch:  1.272mins | Time since start:  56.497mins | Train avg loss =  0.163 | Val avg loss =  0.284 | Val score =  0.7211
# Finished epoch # 45. | Time elapsed during epoch:  1.273mins | Time since start:  57.773mins | Train avg loss =  0.161 | Val avg loss =  0.284 | Val score =  0.7211
# Finished epoch # 46. | Time elapsed during epoch:  1.268mins | Time since start:  59.048mins | Train avg loss =  0.159 | Val avg loss =  0.292 | Val score =  0.7138
# Finished epoch # 47. | Time elapsed during epoch:  1.271mins | Time since start:  60.322mins | Train avg loss =  0.155 | Val avg loss =  0.295 | Val score =  0.7164
# Finished epoch # 48. | Time elapsed during epoch:  1.274mins | Time since start:  61.599mins | Train avg loss =  0.154 | Val avg loss =  0.300 | Val score =  0.7177
# Finished epoch # 49. | Time elapsed during epoch:  1.272mins | Time since start:  62.874mins | Train avg loss =  0.150 | Val avg loss =  0.301 | Val score =  0.7135
# Finished epoch # 50. | Time elapsed during epoch:  1.275mins | Time since start:  64.152mins | Train avg loss =  0.146 | Val avg loss =  0.360 | Val score =  0.7038

# %% [markdown]
# ### Save checkpoint, prepare for part III, etc.
#
# We save the model weights from the best-performing model (the one from the epoch in which the model had the best validation score), as well as its feature embeddings of (i.e., the output of its feature extraction "bottom" portion on) all of the dataset, for later use in Part III below.
#
# (Again, if the relevant switches are turned off, then these parts will be skipped.)

# %%
# Save checkpoint, get feature embeddings, etc

from datetime import datetime



# Save the model that had the best macro AUPRC score

try:
    running_best_model
# Use model itself if no running_best_model has been assigned
except NameError: # running_best_model hasn't been defined yet. Only happens if cells were skipped
    running_best_model = model 
else:
    if running_best_model is None : # this should happen if eg no training was done
        running_best_model = model

# Put the best model in eval mode to "freeze" it
running_best_model.eval()


# Save best model's checkpoint

if SAVE_CHECKPOINT_AFTER_TRAINING :
    checkpoint = {
        'num_epochs_completed': running_best_model._num_epochs,
        'model_state': running_best_model.state_dict(),
        # 'optimizer_state': ... ,
    }
    timestamp = datetime.now().strftime("%Y-%m-%d %H..%M..%S")
    # torch.save(checkpoint, 'Data/Checkpoint/checkpoint.pth') # save without timestamp in filename
    torch.save(checkpoint, f'Data/Checkpoint/checkpoint {timestamp}.pth') # save with timestamp in filename
else :
    print("Did not save checkpoint because SAVE_CHECKPOINT_AFTER_TRAINING is set to False.")


# Save best model's feature embeddings and/or load them

if CALCULATE_FEATURE_EMBS :
    phi_x_np = np.zeros((Num_signals,256))
    with torch.no_grad():
        for i in range(Num_signals) :
            if i % 100 == 0 :
                print(f"Have finished preprocessing {i} of {Num_signals} signals.")
            x,y = full_dataset.__getitem__(i)
            x = x.unsqueeze(0).to(device)
            phi_x_np[i,:] = running_best_model.feature_extraction(x) .detach().cpu().numpy()
    print(f"Have finished preprocessing all {Num_signals} signals.")
    np.save('Data/Postprocessed/feature_embs_from_best_base_model-npy.npy', phi_x_np)
else:
    phi_x_np = np.load('Data/Postprocessed/feature_embs_from_best_base_model-npy.npy')
# Out:
# Have finished preprocessing 0 of 21799 signals.
# Have finished preprocessing 100 of 21799 signals.
# Have finished preprocessing 200 of 21799 signals.
# Have finished preprocessing 300 of 21799 signals.
# Have finished preprocessing 400 of 21799 signals.
# Have finished preprocessing 500 of 21799 signals.
# Have finished preprocessing 600 of 21799 signals.
# Have finished preprocessing 700 of 21799 signals.
# Have finished preprocessing 800 of 21799 signals.
# Have finished preprocessing 900 of 21799 signals.
# Have finished preprocessing 1000 of 21799 signals.
# Have finished preprocessing 1100 of 21799 signals.
# Have finished preprocessing 1200 of 21799 signals.
# Have finished preprocessing 1300 of 21799 signals.
# Have finished preprocessing 1400 of 21799 signals.
# Have finished preprocessing 1500 of 21799 signals.
# Have finished preprocessing 1600 of 21799 signals.
# Have finished preprocessing 1700 of 21799 signals.
# Have finished preprocessing 1800 of 21799 signals.
# Have finished preprocessing 1900 of 21799 signals.
# Have finished preprocessing 2000 of 21799 signals.
# Have finished preprocessing 2100 of 21799 signals.
# Have finished preprocessing 2200 of 21799 signals.
# Have finished preprocessing 2300 of 21799 signals.
# Have finished preprocessing 2400 of 21799 signals.
# Have finished preprocessing 2500 of 21799 signals.
# Have finished preprocessing 2600 of 21799 signals.
# Have finished preprocessing 2700 of 21799 signals.
# Have finished preprocessing 2800 of 21799 signals.
# Have finished preprocessing 2900 of 21799 signals.
# Have finished preprocessing 3000 of 21799 signals.
# Have finished preprocessing 3100 of 21799 signals.
# Have finished preprocessing 3200 of 21799 signals.
# Have finished preprocessing 3300 of 21799 signals.
# Have finished preprocessing 3400 of 21799 signals.
# Have finished preprocessing 3500 of 21799 signals.
# Have finished preprocessing 3600 of 21799 signals.
# Have finished preprocessing 3700 of 21799 signals.
# Have finished preprocessing 3800 of 21799 signals.
# Have finished preprocessing 3900 of 21799 signals.
# Have finished preprocessing 4000 of 21799 signals.
# Have finished preprocessing 4100 of 21799 signals.
# Have finished preprocessing 4200 of 21799 signals.
# Have finished preprocessing 4300 of 21799 signals.
# Have finished preprocessing 4400 of 21799 signals.
# Have finished preprocessing 4500 of 21799 signals.
# Have finished preprocessing 4600 of 21799 signals.
# Have finished preprocessing 4700 of 21799 signals.
# Have finished preprocessing 4800 of 21799 signals.
# Have finished preprocessing 4900 of 21799 signals.
# Have finished preprocessing 5000 of 21799 signals.
# Have finished preprocessing 5100 of 21799 signals.
# Have finished preprocessing 5200 of 21799 signals.
# Have finished preprocessing 5300 of 21799 signals.
# Have finished preprocessing 5400 of 21799 signals.
# Have finished preprocessing 5500 of 21799 signals.
# Have finished preprocessing 5600 of 21799 signals.
# Have finished preprocessing 5700 of 21799 signals.
# Have finished preprocessing 5800 of 21799 signals.
# Have finished preprocessing 5900 of 21799 signals.
# Have finished preprocessing 6000 of 21799 signals.
# Have finished preprocessing 6100 of 21799 signals.
# Have finished preprocessing 6200 of 21799 signals.
# Have finished preprocessing 6300 of 21799 signals.
# Have finished preprocessing 6400 of 21799 signals.
# Have finished preprocessing 6500 of 21799 signals.
# Have finished preprocessing 6600 of 21799 signals.
# Have finished preprocessing 6700 of 21799 signals.
# Have finished preprocessing 6800 of 21799 signals.
# Have finished preprocessing 6900 of 21799 signals.
# Have finished preprocessing 7000 of 21799 signals.
# Have finished preprocessing 7100 of 21799 signals.
# Have finished preprocessing 7200 of 21799 signals.
# Have finished preprocessing 7300 of 21799 signals.
# Have finished preprocessing 7400 of 21799 signals.
# Have finished preprocessing 7500 of 21799 signals.
# Have finished preprocessing 7600 of 21799 signals.
# Have finished preprocessing 7700 of 21799 signals.
# Have finished preprocessing 7800 of 21799 signals.
# Have finished preprocessing 7900 of 21799 signals.
# Have finished preprocessing 8000 of 21799 signals.
# Have finished preprocessing 8100 of 21799 signals.
# Have finished preprocessing 8200 of 21799 signals.
# Have finished preprocessing 8300 of 21799 signals.
# Have finished preprocessing 8400 of 21799 signals.
# Have finished preprocessing 8500 of 21799 signals.
# Have finished preprocessing 8600 of 21799 signals.
# Have finished preprocessing 8700 of 21799 signals.
# Have finished preprocessing 8800 of 21799 signals.
# Have finished preprocessing 8900 of 21799 signals.
# Have finished preprocessing 9000 of 21799 signals.
# Have finished preprocessing 9100 of 21799 signals.
# Have finished preprocessing 9200 of 21799 signals.
# Have finished preprocessing 9300 of 21799 signals.
# Have finished preprocessing 9400 of 21799 signals.
# Have finished preprocessing 9500 of 21799 signals.
# Have finished preprocessing 9600 of 21799 signals.
# Have finished preprocessing 9700 of 21799 signals.
# Have finished preprocessing 9800 of 21799 signals.
# Have finished preprocessing 9900 of 21799 signals.
# Have finished preprocessing 10000 of 21799 signals.
# Have finished preprocessing 10100 of 21799 signals.
# Have finished preprocessing 10200 of 21799 signals.
# Have finished preprocessing 10300 of 21799 signals.
# Have finished preprocessing 10400 of 21799 signals.
# Have finished preprocessing 10500 of 21799 signals.
# Have finished preprocessing 10600 of 21799 signals.
# Have finished preprocessing 10700 of 21799 signals.
# Have finished preprocessing 10800 of 21799 signals.
# Have finished preprocessing 10900 of 21799 signals.
# Have finished preprocessing 11000 of 21799 signals.
# Have finished preprocessing 11100 of 21799 signals.
# Have finished preprocessing 11200 of 21799 signals.
# Have finished preprocessing 11300 of 21799 signals.
# Have finished preprocessing 11400 of 21799 signals.
# Have finished preprocessing 11500 of 21799 signals.
# Have finished preprocessing 11600 of 21799 signals.
# Have finished preprocessing 11700 of 21799 signals.
# Have finished preprocessing 11800 of 21799 signals.
# Have finished preprocessing 11900 of 21799 signals.
# Have finished preprocessing 12000 of 21799 signals.
# Have finished preprocessing 12100 of 21799 signals.
# Have finished preprocessing 12200 of 21799 signals.
# Have finished preprocessing 12300 of 21799 signals.
# Have finished preprocessing 12400 of 21799 signals.
# Have finished preprocessing 12500 of 21799 signals.
# Have finished preprocessing 12600 of 21799 signals.
# Have finished preprocessing 12700 of 21799 signals.
# Have finished preprocessing 12800 of 21799 signals.
# Have finished preprocessing 12900 of 21799 signals.
# Have finished preprocessing 13000 of 21799 signals.
# Have finished preprocessing 13100 of 21799 signals.
# Have finished preprocessing 13200 of 21799 signals.
# Have finished preprocessing 13300 of 21799 signals.
# Have finished preprocessing 13400 of 21799 signals.
# Have finished preprocessing 13500 of 21799 signals.
# Have finished preprocessing 13600 of 21799 signals.
# Have finished preprocessing 13700 of 21799 signals.
# Have finished preprocessing 13800 of 21799 signals.
# Have finished preprocessing 13900 of 21799 signals.
# Have finished preprocessing 14000 of 21799 signals.
# Have finished preprocessing 14100 of 21799 signals.
# Have finished preprocessing 14200 of 21799 signals.
# Have finished preprocessing 14300 of 21799 signals.
# Have finished preprocessing 14400 of 21799 signals.
# Have finished preprocessing 14500 of 21799 signals.
# Have finished preprocessing 14600 of 21799 signals.
# Have finished preprocessing 14700 of 21799 signals.
# Have finished preprocessing 14800 of 21799 signals.
# Have finished preprocessing 14900 of 21799 signals.
# Have finished preprocessing 15000 of 21799 signals.
# Have finished preprocessing 15100 of 21799 signals.
# Have finished preprocessing 15200 of 21799 signals.
# Have finished preprocessing 15300 of 21799 signals.
# Have finished preprocessing 15400 of 21799 signals.
# Have finished preprocessing 15500 of 21799 signals.
# Have finished preprocessing 15600 of 21799 signals.
# Have finished preprocessing 15700 of 21799 signals.
# Have finished preprocessing 15800 of 21799 signals.
# Have finished preprocessing 15900 of 21799 signals.
# Have finished preprocessing 16000 of 21799 signals.
# Have finished preprocessing 16100 of 21799 signals.
# Have finished preprocessing 16200 of 21799 signals.
# Have finished preprocessing 16300 of 21799 signals.
# Have finished preprocessing 16400 of 21799 signals.
# Have finished preprocessing 16500 of 21799 signals.
# Have finished preprocessing 16600 of 21799 signals.
# Have finished preprocessing 16700 of 21799 signals.
# Have finished preprocessing 16800 of 21799 signals.
# Have finished preprocessing 16900 of 21799 signals.
# Have finished preprocessing 17000 of 21799 signals.
# Have finished preprocessing 17100 of 21799 signals.
# Have finished preprocessing 17200 of 21799 signals.
# Have finished preprocessing 17300 of 21799 signals.
# Have finished preprocessing 17400 of 21799 signals.
# Have finished preprocessing 17500 of 21799 signals.
# Have finished preprocessing 17600 of 21799 signals.
# Have finished preprocessing 17700 of 21799 signals.
# Have finished preprocessing 17800 of 21799 signals.
# Have finished preprocessing 17900 of 21799 signals.
# Have finished preprocessing 18000 of 21799 signals.
# Have finished preprocessing 18100 of 21799 signals.
# Have finished preprocessing 18200 of 21799 signals.
# Have finished preprocessing 18300 of 21799 signals.
# Have finished preprocessing 18400 of 21799 signals.
# Have finished preprocessing 18500 of 21799 signals.
# Have finished preprocessing 18600 of 21799 signals.
# Have finished preprocessing 18700 of 21799 signals.
# Have finished preprocessing 18800 of 21799 signals.
# Have finished preprocessing 18900 of 21799 signals.
# Have finished preprocessing 19000 of 21799 signals.
# Have finished preprocessing 19100 of 21799 signals.
# Have finished preprocessing 19200 of 21799 signals.
# Have finished preprocessing 19300 of 21799 signals.
# Have finished preprocessing 19400 of 21799 signals.
# Have finished preprocessing 19500 of 21799 signals.
# Have finished preprocessing 19600 of 21799 signals.
# Have finished preprocessing 19700 of 21799 signals.
# Have finished preprocessing 19800 of 21799 signals.
# Have finished preprocessing 19900 of 21799 signals.
# Have finished preprocessing 20000 of 21799 signals.
# Have finished preprocessing 20100 of 21799 signals.
# Have finished preprocessing 20200 of 21799 signals.
# Have finished preprocessing 20300 of 21799 signals.
# Have finished preprocessing 20400 of 21799 signals.
# Have finished preprocessing 20500 of 21799 signals.
# Have finished preprocessing 20600 of 21799 signals.
# Have finished preprocessing 20700 of 21799 signals.
# Have finished preprocessing 20800 of 21799 signals.
# Have finished preprocessing 20900 of 21799 signals.
# Have finished preprocessing 21000 of 21799 signals.
# Have finished preprocessing 21100 of 21799 signals.
# Have finished preprocessing 21200 of 21799 signals.
# Have finished preprocessing 21300 of 21799 signals.
# Have finished preprocessing 21400 of 21799 signals.
# Have finished preprocessing 21500 of 21799 signals.
# Have finished preprocessing 21600 of 21799 signals.
# Have finished preprocessing 21700 of 21799 signals.
# Have finished preprocessing all 21799 signals.

# %% [markdown]
# # III. Model selection experiment: comparing different classifier heads on top of the pre-trained feature extractor
#
# In this section we do an experiment in which we try replacing the dense classifier head of the base model from earlier with other non-deep classifier heads, and compare all of these models' performances (including the original base model). The model types we use are listed below.
#
# | Model name | Type of classifier head used                     |
# | ---------- | ------------------------------------------------ |
# | A          | (original base model with deep classifier head)  |
# | B          | logistic regressor                               |
# | C          | KNN classifier                                   |
# | D          | decision tree classifier                         |
# | E          | SVC                                              |
# | F          | random forest classifier                         |
#
# In addition to trying the different models, we also vary "num_layers", by which we refer to the number of layers in the original base model's dense classifier head. The results of these experiments can be seen below.
#
# Some details:
# - For Part III we used a test set separate from the validation set (and training set) that was used in training and selecting the base model in Part II. This helps prevent validation leakage.
# - Note num_layers has to be set prior to the training in Part II; this is the NUM_LAYERS_IN_BASE_MODEL_HEAD variable in the "Some base model hyperparameters" section. We don't try multiple values of num_layers in this single notebook; instead, we gathered the data by running the notebook multiple times with num_layers changed each time, and collected the results across these multiple runs.

# %%
# First, in this cell we'll write a wrapper to use our existing base model's dense-layer classifier head, which was built using pytorch,  
# as one of the classifier head models we'll compare using sklearn.

# The dense classifier head will be from the best-performing-model from the training run above.
# However, it will be "frozen", i.e. its weights are now held fixed and the dense classifier doesn't learn further.


from sklearn.base import BaseEstimator, ClassifierMixin


class WrappedFrozenTorchClassifier( ClassifierMixin, BaseEstimator ):

    def __init__(
        self ,
        full_base_model : ECG_Classifier = running_best_model ,
        device = device ,
        batch_size = BATCH_SIZE,
        pred_threshold = DECISION_THRESHOLD_FOR_HARD_PRED
    ):
        self.full_base_model = full_base_model
        self.device = device
        self.batch_size = batch_size
        self.pred_threshold = pred_threshold

    def fit(self, X, y):
        # No training is performed! We only prepare the frozen torch model and set sklearn's fitted attributes.

        # Using "self.full_base_model_" to denote post-fitting self.full_base_model, etc, to match sklearn convention. 
        # (However, the distinction is artificial.)
        
        self.full_base_model_ = self.full_base_model.to(self.device)
        self.full_base_model_.eval()

        for parameter in self.full_base_model_.parameters():
            parameter.requires_grad_(False)

        self.n_features_in_ = X.shape[1]

        # For multilabel indicator targets such as shape (N, 4)
        self.n_outputs_ = y.shape[1]
        self.classes_ = np.arange(self.n_outputs_)

        return self
        

    def _logits(self, X):

        outputs = []

        self.full_base_model_.eval()

        with torch.inference_mode():
            output = self.full_base_model_.classifier_head( 
                torch.tensor(X, dtype=torch.float32).to(device)
            )

        return output

    

    def predict_proba(self, X):
        logits = self._logits(X)

        probabilities = torch.sigmoid(logits).cpu().numpy() # note: don't need detach() because the output from _logits() should already be from a model in inference mode

        return probabilities

    def predict(self, X):
        probabilities = self.predict_proba(X)

        if self.pred_threshold>0.0 :
            return (
                probabilities >= self.threshold_for_scoring
            ).astype(int)
        elif self.pred_threshold==0.0 :
            return (
                probabilities > 0.0
            ).astype(int)

# %%
# In this cell we'll compare the val-set performance of all the models

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

from sklearn.linear_model import LogisticRegression
from sklearn.multioutput import MultiOutputClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

import time

classifier_dict = {
    
    'A' : WrappedFrozenTorchClassifier() ,
    
    'B' : MultiOutputClassifier(
        LogisticRegression(max_iter=3000)
    ) ,
    
    'C' : Pipeline([('ss',StandardScaler()),('knn', KNeighborsClassifier())]) ,
    
    'D' : DecisionTreeClassifier(
        # performance with default parameters was considerably worse and slower,
        # but improved with the below parameters. However, Model D still doesn't perform very well
        max_depth=10,
        min_samples_leaf=5,
        min_samples_split=5,
    ) ,
    
    'E' : MultiOutputClassifier( 
        SVC(kernel='rbf', C=1.0, gamma='scale') 
    ) ,

    'F' : RandomForestClassifier(n_estimators=100, random_state=42) ,
    
}




# Using folds 1-8 as train set, and fold 10 as test set.
# We already technically used fold 9 in selecting model A, so 
# using fold 10 instead of fold 9 as the test set now will prevent leakage.

train_idxlist = []
for i in range(8) : # folds 1-8
    train_idxlist.extend( fold_idxlists[i] )
val_idxlist = fold_idxlists[9] # fold 10

X_full = phi_x_np
y_full = np.stack(ptbxl_annot_data['y_superclasses'].to_numpy())
y_full[ y_full == -1.0 ] = 0.10 # encoding "unknown" confidence as this
X_train = X_full[ train_idxlist  , : ]
y_train = y_full[ train_idxlist  , : ]
X_val = X_full[ val_idxlist  , : ]
y_val = y_full[ val_idxlist  , : ]


# Need hard binary targets
if DECISION_THRESHOLD_FOR_TARGET_IN_SCORING > 0.0 :
    y_train_hard = np.where( y_train >= DECISION_THRESHOLD_FOR_TARGET_IN_SCORING , 1.0 , 0.0 )
    y_val_scoring = np.where( y_val >= DECISION_THRESHOLD_FOR_TARGET_IN_SCORING , 1.0 , 0.0 )
elif DECISION_THRESHOLD_FOR_TARGET_IN_SCORING == 0.0 : 
    y_val_scoring = np.where( y_val > 0.0 , 1.0 , 0.0 )
    y_train_hard = np.where( y_train > 0.0 , 1.0 , 0.0 )

results_dict = {
    'model' : [] ,
    'auprc' : [] ,
    'auroc' : [] ,
}
for letter,model in classifier_dict.items() :

    time_start = time.time()

    if letter=='A' :
        y_train_to_use = y_train
    else :
        # For the sklearn models, we need to use hard 0-or-1 training targets
        y_train_to_use = y_train_hard

    # Train/fit

    model.fit(X_train,y_train_to_use)

    # Get val-set predictions

    if letter=='E' :
        y_pred = np.column_stack([
            estimator.decision_function(X_val)
            for estimator in model.estimators_
        ])
    else :
        proba_list = model.predict_proba(X_val) # using predict_proba instead of predict because we want to use the continuous-valued output for scoring
        if letter=='A' :
            y_pred = proba_list
        else : 
            # For the sklearn models, we need to isolate the positive-class probabilities and drop the negative-class probabilities
            y_pred = np.column_stack([ proba[:, 1] for proba in proba_list ])

    # Get scores
    
    results_dict['model'].append(letter)
    
    macro_auprc = auprc(y_val_scoring, y_pred, average='macro')
    results_dict['auprc'].append(macro_auprc)
    
    macro_auroc = auroc(y_val_scoring, y_pred, average='macro')
    results_dict['auroc'].append(macro_auroc)

    time_now = time.time()
    print(f"Finished validating model {letter}.", end=' ')
    print(f"Time elapsed: {(time_now-time_start) : .3f}s")



print("\nTest score results:")
print( pd.DataFrame(results_dict).set_index('model').to_string() )


""" 
Uncomment the below to write the results to a hard disk. We've already collected some results included in this Github project.
"""

# # Log the results in a csv file

# with open("Results from different classifier heads for different num_layers.csv", "a") as file:
#     for m in ['A','B','F'] :
#         file.write(f"{NUM_LAYERS_IN_BASE_MODEL_HEAD},{m},{ 
#             results_dict['auprc'][ list(classifier_dict.keys()).index(m) ]
#         }\n")



None # prints nothing to prevent the comment from being printed
# Out:
# Finished validating model A. Time elapsed:  0.080s
# Finished validating model B. Time elapsed:  0.475s
# Finished validating model C. Time elapsed:  0.134s
# Finished validating model D. Time elapsed:  3.138s
# Finished validating model E. Time elapsed:  21.850s
# Finished validating model F. Time elapsed:  23.686s
#
# Test score results:
#           auprc     auroc
# model
# A      0.740341  0.900012
# B      0.741390  0.902229
# C      0.631228  0.848109
# D      0.637318  0.832510
# E      0.706188  0.839696
# F      0.726669  0.896125

# %% [markdown]
# ## Results
#
# As seen from the graph below, for 2≤num_layers≤5, the base Model A still outperforms all other models. However, interestingly, **the best overall performance** is attained by Model B (consisting of a logistic regression head chained after our pre-trained feature extractor from Part II) with num_layers=1. In fact, with num_layers=1, Model B even outperformed the original Model A.
#
# - We only kept data for Models A,B,F as these were consistently the best-performing models.
# - See the "Results" folder for a csv containing the results of multiple runs with different models and different choices of num_layers.
# - We see the performance for each of these models degrades as num_layers increases. This suggests that for our base model design, configurations with num_layers>1 tend to overfit on the training set.
# - Note: Model A's head is just a single dense layer with sigmoid activation, which is essentially the same as the logistic regression head of Model B, except it has a different regularization system and was trained in a completely different way.

# %%
# Code to show average test score for different models for different values of num_layers

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from cycler import cycler
from matplotlib.ticker import MaxNLocator

def DISPLAY_COMPARISON() :

    scores_df = pd.read_csv("Results/Results from different classifier heads for different num_layers.csv", header=None)
    scores_df.columns = ['num_layers', 'model', 'test_score(auprc)']


    fig,ax = plt.subplots()
    colors = plt.get_cmap('tab20') ( np.array([0,5,10]) ) # colors using the tab20 palette
    plt.gca().set_prop_cycle(cycler(color=colors)) # set the graph to use these colors

    m_list = ['A','B','F']
    num_list = [ i for i in range(1,7) ]

    scores = { m:[] for m in m_list }

    for m in m_list :

        for n in num_list.copy() : # using a copy because we might remove entries from num_list

            relevant_scores = scores_df[
                    ( scores_df['model']==m ) & ( scores_df['num_layers']==n )
                ]['test_score(auprc)']
                # scores achieved by model m with num_layers=n

            if relevant_scores.empty :
                # model m with num_layers=n hasn't happened yet, which means num_layers=n hasn't happened yet
                #  (so it doesn't matter what m is right now. in fact m should be the first entry in m_list)
                # remove n so it doesn't get plotted (i.e. it doesn't show up in the x-axis)
                if n in num_list :
                    num_list.remove(n)
            else :
                score_avg = relevant_scores.mean()
                scores[m].append( score_avg )


        ax.plot( num_list , scores[m] ,
                 label = (
                         f'Model A (base)' if m=='A'
                    else f'Model B (log reg head)' if m=='B'
                    else f'Model F (random forest head)' if m=='F'
                    else None
                 )
                )



    ax.xaxis.set_major_locator(MaxNLocator(integer=True)) # force integer ticks on the X-axis

    ax.set_title("Test score for part III models");
    ax.set_xlabel("num_layers")
    ax.set_ylabel("Test score (AUPRC, averaged over runs)")
    ax.legend()
    plt.savefig("Results/part III model comparison.png", bbox_inches="tight", dpi=300)
    plt.show()



DISPLAY_COMPARISON()
